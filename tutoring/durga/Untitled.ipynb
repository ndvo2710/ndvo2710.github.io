# %% [markdown]
# # Session 1:
#
# ## Functions:
#
# ![image](https://dl.dropboxusercontent.com/u/27868566/shots/shot_2016-09-13_01-48-44.png)
#
# ![image](https://dl.dropboxusercontent.com/u/27868566/shots/shot_2016-09-13_01-48-56.png)
#
# ![image](https://dl.dropboxusercontent.com/u/27868566/shots/shot_2016-09-13_01-49-19.png)
#
# ![image](https://dl.dropboxusercontent.com/u/27868566/shots/shot_2016-09-13_01-49-28.png)
#
# ![image](https://dl.dropboxusercontent.com/u/27868566/shots/shot_2016-09-13_01-49-50.png)
#
# ![image](https://dl.dropboxusercontent.com/u/27868566/shots/shot_2016-09-13_01-50-01.png)
#
# ### Now you know more about function, but keep in mind that: 1 INPUT NEVER HAVE MORE THAN 1 OUTPUT
#
# So, Let's try some exercises to test your understanding about function:
#
# <b><u>Question 1:</u></b>
#
# ![image](https://dl.dropboxusercontent.com/u/27868566/shots/shot_2016-09-13_01-55-26.png)
#
# <b><u>Question 2:</u></b>
#
# ![image](https://dl.dropboxusercontent.com/u/27868566/shots/shot_2016-09-13_01-56-00.png)
#
# <b><u>Question 3:</u></b>
#
# ![image](https://dl.dropboxusercontent.com/u/27868566/shots/shot_2016-09-13_01-56-32.png)
#
# <b><u>Question 4:</u></b>
#
# ![image](https://dl.dropboxusercontent.com/u/27868566/shots/shot_2016-09-13_01-57-19.png)
#
# <b><u>Question 5:</u></b>
#
# ![image](https://dl.dropboxusercontent.com/u/27868566/shots/shot_2016-09-13_01-57-47.png)
#
# ## Parents Functions and Transformation:
#
# Here are some parent functions that are introduced by the textbook:
#
# ![image](https://dl.dropboxusercontent.com/u/27868566/shots/shot_2016-09-13_02-00-39.png)
#
# I think you will have no problem dealing with exercises related to constant or linear. So we will try to deal with Absolute Value and Quaratic
#
# <b>Keep in mind:</b>
#
# ```
# Step 1: Find the linear group.
# Step 2: Find the vertex.(Linear group = 0)
# Step 3: Transformation
#
# ```
#
# #### STEP 1: FIND LINEAR GROUP:
#
# Let's try some example of identifying the linear group of these functions:
#
# ##### Ex1:
#
# $g(x) = |x+2| - 1$
#
# Ans: Linear group is x+2
#
# ##### Ex2:
#
# $f(x) = 2 - \frac{5}{2}|x-7|$
#
# Ans: Linear group is x-7
#
# ##### Ex3:
#
# $f(x) = (x-5)^2 + 3$
#
# Ans: Linear group is x-5
#
# ##### Ex4:
#
# $h(x) = 3(2x+3)^2 -2$
#
# Ans: Linear group is 2x+3
#
# #### STEP 2: FIND VERTEX:
#
# ```
# To find vertex:
#
# a) Let (linear group) = 0
# => Find x-value (This is vertex's x-value)
#
# b) Find y-value of vertex by plugging x-value into a function
# ```
#
# ##### Ex1:
#
# $g(x) = |x+2| - 1$
#
# x + 2 = 0 => x = -2
#
# When x = -2 => g(-2) = -1
#
# So vertex is (-2,-1)
#
#
# ##### Ex2:
#
# $f(x) = 2 - \frac{5}{2}|x-7|$
#
# x - 7 = 0  => x = 7
#
# When x = 7 => f(7) = 2
#
# So vertex is (7,2)
#
# ##### Ex3:
#
# $f(x) = (x-5)^2 + 3$
#
# Now, you can do it in your head:
#
# So vertex is (5,3)
#
# ##### Ex4:
#
# $h(x) = 3(2x+3)^2 -2$
#
# So vertex is (-3/2, -2)
#
#
# #### STEP 3: TRANSFORMATION
#
#
# ##### Ex1:
#
# $g(x) = |x+2| - 1$
#
# ![image](https://dl.dropboxusercontent.com/u/27868566/shots/shot_2016-09-13_02-36-22.png)
#
# Since the vertex that we find is (-2,-1), we can see that the vertext has already tells us how the graph will move:
#
# x = -2 means the original graph (orange color) will move to the left 2 unit
# y = -1 mneas the orginal graph (orange color) will move down 1 unit
#
# Basically, the original graph move to the left 2 unit and move down 1 unit.
#
# (Do you see the vertex of the original graph which is (0,0) has moved to (-2,-1) ?)
#
#
# ##### Ex2:
#
# $f(x) = 2 - \frac{5}{2}|x-7|$
#
# Now we can guess our vertex will move from (0,0) to (7,2)
#
# ![image](https://dl.dropboxusercontent.com/u/27868566/shots/shot_2016-09-13_02-44-23.png)
#
# BE CAREFUL! We have the scale (5/2) in front of linear group. So do it slowly:
#
# ###### First Transformation:
#
# ![image](https://dl.dropboxusercontent.com/u/27868566/shots/shot_2016-09-13_02-50-03.png)
#
# ###### Second Transformation: (Deal with sign of the linear group)
#
# ![image](https://dl.dropboxusercontent.com/u/27868566/shots/shot_2016-09-13_02-50-32.png)
#
# ###### Third Transformation: (Deal with scale and sign of the linear group)
#
# ![image](https://dl.dropboxusercontent.com/u/27868566/shots/shot_2016-09-13_02-52-27.png)
#
# ###### Fourth Transformation:
#
# ![image](https://dl.dropboxusercontent.com/u/27868566/shots/shot_2016-09-13_02-52-43.png)
#
# ###### Final Result:
#
# You can compare the final transformation to the original graph.
#
# The whole process could be explained as: The original graph flips upside down, scale with -5/2, then the graph moves along with the vertex from (0,0) to (7,2)
#
# ![image](https://dl.dropboxusercontent.com/u/27868566/shots/shot_2016-09-13_02-54-41.png)
#
# ##### Ex3:
#
# $f(x) = (x-5)^2 + 3$
#
# Same things are applied as the above two examples:
#
# ![image](https://dl.dropboxusercontent.com/u/27868566/shots/shot_2016-09-13_03-01-50.png)
#
# Notice that: when we don't have the scale factor, the graph just move from the original vertex to the vertex that we find ( In this case, move from (0,0) to (5,3))
#
# ##### Ex4:
#
# $h(x) = 3(2x+3)^2 -2$
#
# BE CAREFUL! DO YOU NOTICE THE SCALE FACTOR OF 2 INSIDE THE LINEAR GROUP AND THE SCALE OF 3 OUTSIDE THE LINEAR GROUP.
#
#
# ###### First Transformation:
#
# ![image](https://dl.dropboxusercontent.com/u/27868566/shots/shot_2016-09-13_03-12-00.png)
#
# ###### Second Transformation:
#
# ![image](https://dl.dropboxusercontent.com/u/27868566/shots/shot_2016-09-13_03-12-14.png)
#
# ###### Third Transformation:
#
# ![image](https://dl.dropboxusercontent.com/u/27868566/shots/shot_2016-09-13_03-12-27.png)
#
# ###### Fourth Transformation:
#
# ![image](https://dl.dropboxusercontent.com/u/27868566/shots/shot_2016-09-13_03-12-38.png)
#
# ###### Final Result:
#
# The original graph is orange.
# The transformation graph is green.
#
# ![image](https://dl.dropboxusercontent.com/u/27868566/shots/shot_2016-09-13_03-13-11.png)
#
#
# ## HOMEWORK:
#
# You do not need to show work, just graph all the transformation and vertex ( I will teach you how to write your results formally later):
#
# <b><u>Question 1:</u></b>
#
# $f(x) = |1-x| -5$
#
# <b><u>Question 2:</u></b>
#
# $f(x) = |5-\frac{9x}{8}| +4$
#
# <b><u>Question 3:</u></b>
#
# $f(x) = 3 -(x +2)^2$
#
# <b><u>Question 4:</u></b>
#
# $f(x) = 2 + 3(5x + 1)^2$
#
#
# <u>Question 5 and 6 are difficult. However, I have shown you how to deal with these types of problems. Try to do these two questions and I will go over these again next week.</u>
#
# <b><u>Question 5:</u></b>
#
# $f(x) = x^2 + 2x$
#
# <b><u>Question 6:</u></b>
#
# $f(x) = 3x^2 + x + 1$
